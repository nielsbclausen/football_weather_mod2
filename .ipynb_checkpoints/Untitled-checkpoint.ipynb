# %%
import sqlite3
import pandas as pd
from bs4 import BeautifulSoup as BS
import numpy as np
import json
from statistics import mode
from scipy import stats

# %%
connection = sqlite3.connect("database.sqlite")

cur = connection.cursor()

# %%
cur.execute("""SELECT *
                FROM Matches
                WHERE Date BETWEEN '2010-12-31' and '2011-12-31'
                JOIN Unique_Teams
                ON Matches.HomeTeam = Unique_Teams.TeamName;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
hometeams = df['HomeTeam'].unique()
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-107-e9c5a7fe8288> in <module>
#       3                 WHERE Date BETWEEN '2010-12-31' and '2011-12-31'
#       4                 JOIN Unique_Teams
# ----> 5                 ON Matches.HomeTeam = Unique_Teams.TeamName""")
#       6 df = pd.DataFrame(cur.fetchall())
#       7 df.columns = [x[0] for x in cur.description]
#
# OperationalError: near "JOIN": syntax error

# %%
cur.execute("""SELECT *
                FROM Matches
                WHERE Date BETWEEN '2010-12-31' and '2011-12-31'
                ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
hometeams = df['HomeTeam'].unique()
df
# Out:
#       Match_ID Div  Season        Date       HomeTeam       AwayTeam  FTHG  \
# 0          481  D1    2010  2011-01-15      Wolfsburg  Bayern Munich     1
# 1          483  D1    2010  2011-04-23  Ein Frankfurt  Bayern Munich     1
# 2          485  D1    2010  2011-03-05       Hannover  Bayern Munich     3
# 3          489  D1    2010  2011-01-29  Werder Bremen  Bayern Munich     1
# 4          490  D1    2010  2011-02-05        FC Koln  Bayern Munich     3
# ...        ...  ..     ...         ...            ...            ...   ...
# 1003     44677  E0    2011  2011-12-31        Chelsea    Aston Villa     1
# 1004     44678  E0    2011  2011-12-31     Man United      Blackburn     2
# 1005     44679  E0    2011  2011-12-31        Norwich         Fulham     1
# 1006     44680  E0    2011  2011-12-31          Stoke          Wigan     2
# 1007     44681  E0    2011  2011-12-31        Swansea      Tottenham     1
#
#       FTAG FTR
# 0        1   D
# 1        1   D
# 2        1   H
# 3        3   A
# 4        2   H
# ...    ...  ..
# 1003     3   A
# 1004     3   A
# 1005     1   D
# 1006     2   D
# 1007     1   D
#
# [1008 rows x 9 columns]

# %%
cur.execute("""SELECT *
                FROM Matches
                ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
s11 = df[df['Season']==2011]
germs = s11[s11['Div']!='E0']
for date in germs['Date']:
    time = date
    url = ''
    weather = requests.get(url)

# %%
query = """
        SELECT *
        FROM Matches
        """
# JOIN Teams_in_Matches ON Matches.Match_ID = Teams_in_Matches
df = pd.DataFrame(cur.execute(query).fetchall())
df.columns = [x[0] for x in cur.description]
s11 = df[df['Season']==2011]
s11germ = s11[s11['Div']!='E0']
lat = 52.5065133
long = 13.1445703
weather = []
# for date in s11germ['Date']:
# #     print(date)
#     time = date
#     url='https://api.darksky.net/forecast/{}/{},{},{}T16:00:00'.format(apikey,lat,long,time)
# #     print(url)
#     response = requests.get(url)
#     weather.append(response.text)
# weather

# %%
class WeatherGetter(object):
    def __init__(self):
        self.lat = 52.5065133
        self.long = 13.1445703
        self.time = date
        self.apikey = '/Users/nielsclausen/Desktop/data/KEYS/APIKEY'
        
        
    def date(self):
# Out:
#   File "<ipython-input-162-2dcb8280ffaf>", line 10
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# object = teams
# run it through so that each team has stats x weather

# %%
for date in s11germ['Date']:
    time = date
    url = 'https://api.darksky.net/forecast/{}/{},{},{}T16:00:00'.format(apikey,lat,long,time)
    print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-131331d198de> in <module>
#       1 for date in s11germ['Date']:
#       2     time = date
# ----> 3     url = 'https://api.darksky.net/forecast/{}/{},{},{}T16:00:00'.format(apikey,lat,long,time)
#       4     print(url)
#
# NameError: name 'apikey' is not defined
